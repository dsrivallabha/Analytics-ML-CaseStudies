# %% [markdown]
# ## Titanic Original DataSet

# %% [markdown]
# Dataset downloaded from
# biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('./Data/OriginalTitanicDataSet.csv')
print (len(titanic))
print (titanic.columns)
# Out:
# 1309
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
sum(titanic.age.isnull())
# Out:
# 263

# %%
t1 = titanic[titanic['age'].isna()]
t1.describe()
# Out:
#            pclass    survived  age       sibsp       parch        fare   body
# count  263.000000  263.000000  0.0  263.000000  263.000000  263.000000    1.0
# mean     2.642586    0.277567  NaN    0.482890    0.243346   19.823319  153.0
# std      0.726812    0.448652  NaN    1.448443    0.949941   27.550667    NaN
# min      1.000000    0.000000  NaN    0.000000    0.000000    0.000000  153.0
# 25%      3.000000    0.000000  NaN    0.000000    0.000000    7.750000  153.0
# 50%      3.000000    0.000000  NaN    0.000000    0.000000    8.050000  153.0
# 75%      3.000000    1.000000  NaN    0.000000    0.000000   22.804150  153.0
# max      3.000000    1.000000  NaN    8.000000    9.000000  227.525000  153.0

# %%
t2 = titanic[~titanic['age'].isna()]
print (len(t2))
# Out:
# 1046

# %%
t2[t2['age'] == 25]
# Out:
#       pclass  survived                                             name  \
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 25         1         0                              Birnbaum, Mr. Jakob
# 26         1         1                          Bishop, Mr. Dickinson H
# 143        1         1                      Harder, Mr. George Achilles
# 144        1         1     Harder, Mrs. George Achilles (Dorothy Annan)
# 327        2         0                         Andrew, Mr. Frank Thomas
# 354        2         0                  Bryhl, Mr. Kurt Arnold Gottfrid
# 356        2         0                      Butler, Mr. Reginald Fenton
# 370        2         1                      Christy, Miss. Julie Rachel
# 393        2         0                             Denbury, Mr. Herbert
# 480        2         0           Laroche, Mr. Joseph Philippe Lemercier
# 555        2         0       Sedgwick, Mr. Charles Frederick Waddington
# 557        2         1     Shelley, Mrs. William (Imanita Parrish Hall)
# 565        2         0                   Sobey, Mr. Samuel James Hayden
# 567        2         0                        Stokes, Mr. Philip Joseph
# 605        3         1                    Abelseth, Mr. Olaus Jorgensen
# 617        3         0                                 Ali, Mr. William
# 635        3         0                        Arnold-Franchi, Mr. Josef
# 751        3         0                            Dantcheff, Mr. Ristiu
# 766        3         0                               Delalic, Mr. Redjo
# 814        3         0                            Gallagher, Mr. Martin
# 853        3         0               Harmer, Mr. Abraham (David Lishin)
# 878        3         0                    Ilmakangas, Miss. Pieta Sofia
# 941        3         1                            Krekorian, Mr. Neshan
# 966        3         0            Lindahl, Miss. Agda Thorilda Viktoria
# 1024       3         0                          Moen, Mr. Sigurd Hansen
# 1118       3         0                  Peltomaki, Mr. Nikolai Johannes
# 1120       3         1                         Persson, Mr. Ernst Ulrik
# 1129       3         0                        Petterson, Mr. Johan Emil
# 1165       3         0                                 Saad, Mr. Khalil
# 1190       3         1                                  Sap, Mr. Julius
# 1234       3         0                           Sutehall, Mr. Henry Jr
# 1238       3         1                       Tenglin, Mr. Gunnar Isidor
# 1254       3         1                     Tornquist, Mr. William Henry
#
#          sex   age  sibsp  parch              ticket      fare    cabin  \
# 4     female  25.0      1      2              113781  151.5500  C22 C26
# 25      male  25.0      0      0               13905   26.0000      NaN
# 26      male  25.0      1      0               11967   91.0792      B49
# 143     male  25.0      1      0               11765   55.4417      E50
# 144   female  25.0      1      0               11765   55.4417      E50
# 327     male  25.0      0      0          C.A. 34050   10.5000      NaN
# 354     male  25.0      1      0              236853   26.0000      NaN
# 356     male  25.0      0      0              234686   13.0000      NaN
# 370   female  25.0      1      1              237789   30.0000      NaN
# 393     male  25.0      0      0          C.A. 31029   31.5000      NaN
# 480     male  25.0      1      2       SC/Paris 2123   41.5792      NaN
# 555     male  25.0      0      0              244361   13.0000      NaN
# 557   female  25.0      0      1              230433   26.0000      NaN
# 565     male  25.0      0      0          C.A. 29178   13.0000      NaN
# 567     male  25.0      0      0        F.C.C. 13540   10.5000      NaN
# 605     male  25.0      0      0              348122    7.6500    F G63
# 617     male  25.0      0      0  SOTON/O.Q. 3101312    7.0500      NaN
# 635     male  25.0      1      0              349237   17.8000      NaN
# 751     male  25.0      0      0              349203    7.8958      NaN
# 766     male  25.0      0      0              349250    7.8958      NaN
# 814     male  25.0      0      0               36864    7.7417      NaN
# 853     male  25.0      0      0              374887    7.2500      NaN
# 878   female  25.0      1      0    STON/O2. 3101271    7.9250      NaN
# 941     male  25.0      0      0                2654    7.2292    F E57
# 966   female  25.0      0      0              347071    7.7750      NaN
# 1024    male  25.0      0      0              348123    7.6500    F G73
# 1118    male  25.0      0      0   STON/O 2. 3101291    7.9250      NaN
# 1120    male  25.0      1      0              347083    7.7750      NaN
# 1129    male  25.0      1      0              347076    7.7750      NaN
# 1165    male  25.0      0      0                2672    7.2250      NaN
# 1190    male  25.0      0      0              345768    9.5000      NaN
# 1234    male  25.0      0      0     SOTON/OQ 392076    7.0500      NaN
# 1238    male  25.0      0      0              350033    7.7958      NaN
# 1254    male  25.0      0      0                LINE    0.0000      NaN
#
#      embarked   boat   body                        home.dest
# 4           S    NaN    NaN  Montreal, PQ / Chesterville, ON
# 25          C    NaN  148.0                San Francisco, CA
# 26          C      7    NaN                     Dowagiac, MI
# 143         C      5    NaN                     Brooklyn, NY
# 144         C      5    NaN                     Brooklyn, NY
# 327         S    NaN    NaN   Cornwall, England Houghton, MI
# 354         S    NaN    NaN     Skara, Sweden / Rockford, IL
# 356         S    NaN   97.0                  Southsea, Hants
# 370         S     12    NaN                           London
# 393         S    NaN    NaN         Guernsey / Elizabeth, NJ
# 480         C    NaN    NaN                    Paris / Haiti
# 555         S    NaN    NaN                        Liverpool
# 557         S     12    NaN                   Deer Lodge, MT
# 565         S    NaN    NaN          Cornwall / Houghton, MI
# 567         S    NaN   81.0      Catford, Kent / Detroit, MI
# 605         S      A    NaN               Perkins County, SD
# 617         S    NaN   79.0                        Argentina
# 635         S    NaN    NaN             Altdorf, Switzerland
# 751         S    NaN    NaN             Bulgaria Chicago, IL
# 766         S    NaN    NaN                              NaN
# 814         Q    NaN    NaN                     New York, NY
# 853         S      B    NaN                              NaN
# 878         S    NaN    NaN                              NaN
# 941         C     10    NaN                              NaN
# 966         S    NaN    NaN                              NaN
# 1024        S    NaN  309.0                              NaN
# 1118        S    NaN    NaN                              NaN
# 1120        S     15    NaN                              NaN
# 1129        S    NaN    NaN                              NaN
# 1165        C    NaN    NaN                              NaN
# 1190        S     11    NaN                              NaN
# 1234        S    NaN    NaN                              NaN
# 1238        S  13 15    NaN                              NaN
# 1254        S     15    NaN                              NaN

# %%
a = t2[t2['name'].apply(lambda x: 'George' in x)]

# %%
t2[t2['name'].str.contains('George')]
# Out:
#       pclass  survived                                             name  \
# 135        1         0                        Goldschmidt, Mr. George B
# 138        1         0                        Graham, Mr. George Edward
# 143        1         1                      Harder, Mr. George Achilles
# 144        1         1     Harder, Mrs. George Achilles (Dorothy Annan)
# 193        1         1                Madill, Miss. Georgette Alexandra
# 234        1         0                  Reuchlin, Jonkheer. John George
# 243        1         0      Rosenshine, Mr. George ("Mr George Thorne")
# 284        1         1        Stone, Mrs. George Nelson (Martha Evelyn)
# 310        1         0                         Wick, Mr. George Dennick
# 311        1         1       Wick, Mrs. George Dennick (Mary Hitchcock)
# 312        1         0                       Widener, Mr. George Dunton
# 314        1         1     Widener, Mrs. George Dunton (Eleanor Elkins)
# 321        1         0                               Wright, Mr. George
# 403        2         0                     Eitemiller, Mr. George Floyd
# 432        2         1                               Harris, Mr. George
# 444        2         0                      Hickman, Mr. Stanley George
# 447        2         0                      Hocking, Mr. Richard George
# 457        2         0                           Hunt, Mr. George Henry
# 548        2         1                  Richards, Master. George Sibley
# 568        2         0                                Swane, Mr. George
# 569        2         0                      Sweet, Mr. George Frederick
# 619        3         0                           Allum, Mr. Owen George
# 765        3         1         Dean, Mrs. Bertram (Eva Georgetta Light)
# 833        3         0                          Green, Mr. George Henry
# 1108       3         0                             Patchett, Mr. George
# 1145       3         0                        Rice, Master. George Hugh
# 1161       3         0                     Rush, Mr. Alfred George John
# 1256       3         1                   Touma, Master. Georges Youssef
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
#
#          sex    age  sibsp  parch        ticket      fare cabin embarked boat  \
# 135     male  71.00      0      0      PC 17754   34.6542    A5        C  NaN
# 138     male  38.00      0      1      PC 17582  153.4625   C91        S  NaN
# 143     male  25.00      1      0         11765   55.4417   E50        C    5
# 144   female  25.00      1      0         11765   55.4417   E50        C    5
# 193   female  15.00      0      1         24160  211.3375    B5        S    2
# 234     male  38.00      0      0         19972    0.0000   NaN        S  NaN
# 243     male  46.00      0      0      PC 17585   79.2000   NaN        C  NaN
# 284   female  62.00      0      0        113572   80.0000   B28      NaN    6
# 310     male  57.00      1      1         36928  164.8667   NaN        S  NaN
# 311   female  45.00      1      1         36928  164.8667   NaN        S    8
# 312     male  50.00      1      1        113503  211.5000   C80        C  NaN
# 314   female  50.00      1      1        113503  211.5000   C80        C    4
# 321     male  62.00      0      0        113807   26.5500   NaN        S  NaN
# 403     male  23.00      0      0         29751   13.0000   NaN        S  NaN
# 432     male  62.00      0      0   S.W./PP 752   10.5000   NaN        S   15
# 444     male  21.00      2      0  S.O.C. 14879   73.5000   NaN        S  NaN
# 447     male  23.00      2      1         29104   11.5000   NaN        S  NaN
# 457     male  33.00      0      0    SCO/W 1585   12.2750   NaN        S  NaN
# 548     male   0.83      1      1         29106   18.7500   NaN        S    4
# 568     male  18.50      0      0        248734   13.0000     F        S  NaN
# 569     male  14.00      0      0        220845   65.0000   NaN        S  NaN
# 619     male  18.00      0      0          2223    8.3000   NaN        S  NaN
# 765   female  33.00      1      2     C.A. 2315   20.5750   NaN        S   10
# 833     male  51.00      0      0         21440    8.0500   NaN        S  NaN
# 1108    male  19.00      0      0        358585   14.5000   NaN        S  NaN
# 1145    male   8.00      4      1        382652   29.1250   NaN        Q  NaN
# 1161    male  16.00      0      0    A/4. 20589    8.0500   NaN        S  NaN
# 1256    male   7.00      1      1          2650   15.2458   NaN        C    C
# 1286  female  38.00      0      0          2688    7.2292   NaN        C    C
#
#        body                             home.dest
# 135     NaN                          New York, NY
# 138   147.0                          Winnipeg, MB
# 143     NaN                          Brooklyn, NY
# 144     NaN                          Brooklyn, NY
# 193     NaN                          St Louis, MO
# 234     NaN                Rotterdam, Netherlands
# 243    16.0                          New York, NY
# 284     NaN                        Cincinatti, OH
# 310     NaN                        Youngstown, OH
# 311     NaN                        Youngstown, OH
# 312     NaN                       Elkins Park, PA
# 314     NaN                       Elkins Park, PA
# 321     NaN                           Halifax, NS
# 403     NaN                 England / Detroit, MI
# 432     NaN                                London
# 444     NaN  West Hampstead, London / Neepawa, MB
# 447     NaN                  Cornwall / Akron, OH
# 457     NaN                      Philadelphia, PA
# 548     NaN                  Cornwall / Akron, OH
# 568   294.0                                   NaN
# 569     NaN          Somerset / Bernardsville, NJ
# 619   259.0         Windsor, England New York, NY
# 765     NaN            Devon, England Wichita, KS
# 833     NaN              Dorking, Surrey, England
# 1108    NaN                                   NaN
# 1145    NaN                                   NaN
# 1161    NaN                                   NaN
# 1256    NaN                                   NaN
# 1286    NaN                                   NaN

# %%
1046 + 263
# Out:
# 1309

# %%
t2.describe()
# Out:
#             pclass     survived          age        sibsp       parch  \
# count  1046.000000  1046.000000  1046.000000  1046.000000  1046.00000
# mean      2.207457     0.408222    29.881138     0.502868     0.42065
# std       0.841497     0.491740    14.413493     0.912167     0.83975
# min       1.000000     0.000000     0.170000     0.000000     0.00000
# 25%       1.000000     0.000000    21.000000     0.000000     0.00000
# 50%       2.000000     0.000000    28.000000     0.000000     0.00000
# 75%       3.000000     1.000000    39.000000     1.000000     1.00000
# max       3.000000     1.000000    80.000000     8.000000     6.00000
#
#               fare       body
# count  1045.000000  120.00000
# mean     36.686080  160.87500
# std      55.732533   98.10392
# min       0.000000    1.00000
# 25%       8.050000   71.50000
# 50%      15.750000  155.50000
# 75%      35.500000  256.50000
# max     512.329200  328.00000

# %%
t3 = t2[~t2.fare.isna()]
print (len(t3))
# Out:
# 1045

# %%
t3.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1045.000000  1045.000000  1045.000000  1045.000000  1045.000000
# mean      2.206699     0.408612    29.851837     0.503349     0.421053
# std       0.841542     0.491813    14.389194     0.912471     0.840052
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       1.000000     0.000000    21.000000     0.000000     0.000000
# 50%       2.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     1.000000
# max       3.000000     1.000000    80.000000     8.000000     6.000000
#
#               fare        body
# count  1045.000000  119.000000
# mean     36.686080  160.033613
# std      55.732533   98.082975
# min       0.000000    1.000000
# 25%       8.050000   71.000000
# 50%      15.750000  155.000000
# 75%      35.500000  255.500000
# max     512.329200  328.000000

# %%
t3.iloc[0]
# Out:
# pclass                                   1
# survived                                 1
# name         Allen, Miss. Elisabeth Walton
# sex                                 female
# age                                     29
# sibsp                                    0
# parch                                    0
# ticket                               24160
# fare                               211.338
# cabin                                   B5
# embarked                                 S
# boat                                     2
# body                                   NaN
# home.dest                     St Louis, MO
# Name: 0, dtype: object

# %%
t4 = titanic.dropna(axis=0)

# %%
print (len(t4))
# Out:
# 0

# %%
a = t3.groupby(['survived'])

# %%
#titanic.sns.boxplot(column='age', by=['survived'])

sns.boxplot(x='survived', y='age', data=titanic)

sns.boxplot(x='survived', y='pclass', data=titanic)

sns.boxplot(x='pclass', y='survived', data=titanic)

sns.barplot(x='pclass', y='survived', data=titanic)

# %% [markdown]
# ## Exploratory analysis

# %% [markdown]
# ### Check the number of passengers & demography

# %%
print (len(t3))
# Out:
# 1045

# %%
print (t3.groupby(['sex'])['name'].count())
print (len(t3))
t3.groupby(['sex'])['name'].count().plot(kind='pie', autopct='%1.0f%%')
plt.ylabel('gender')
plt.axis('equal')
plt.show()
# Out:
# sex
# female    388
# male      657
# Name: name, dtype: int64
# 1045

# %%
print (t3.groupby(['survived'])['name'].count())
t3.groupby(['survived'])['name'].count().plot(kind='pie', autopct='%1.0f%%')
plt.ylabel('survived')
plt.axis('equal')
plt.show()
# Out:
# survived
# 0    618
# 1    427
# Name: name, dtype: int64

# %%
print (t3.groupby(['pclass'])['name'].count())
t3.groupby(['pclass'])['name'].count().plot(kind='pie', autopct='%1.0f%%')
plt.ylabel('pclass')
plt.axis('equal')
plt.show()
# Out:
# pclass
# 1    284
# 2    261
# 3    500
# Name: name, dtype: int64

# %%
abins = pd.IntervalIndex.from_tuples([(0, 20), (20, 40), (40, 60), (60, 80), (80,100)])
t3['agebins'] = pd.cut(t3['age'], abins)
# Out:
# /home/srivallabha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
t3.agebins.head()
# Out:
# 0    (20, 40]
# 1     (0, 20]
# 2     (0, 20]
# 3    (20, 40]
# 4    (20, 40]
# Name: agebins, dtype: category
# Categories (5, interval[int64]): [(0, 20] < (20, 40] < (40, 60] < (60, 80] < (80, 100]]

# %%
print (t3.groupby(['agebins'])['name'].count())
t3.groupby(['agebins'])['name'].count().plot(kind='pie', autopct='%1.0f%%')
plt.ylabel('age groups')
plt.axis('equal')
plt.show()
# Out:
# agebins
# (0, 20]      248
# (20, 40]     571
# (40, 60]     194
# (60, 80]      32
# (80, 100]      0
# Name: name, dtype: int64

# %%
print (t3.groupby(['sibsp'])['name'].count())
t3.groupby(['sibsp'])['name'].count().plot(kind='bar')
plt.show()
# Out:
# sibsp
# 0    684
# 1    280
# 2     36
# 3     16
# 4     22
# 5      6
# 8      1
# Name: name, dtype: int64

# %%
print (t3.groupby(['parch'])['name'].count())
t3.groupby(['parch'])['name'].count().plot(kind='bar')
plt.show()
# Out:
# parch
# 0    767
# 1    160
# 2     97
# 3      8
# 4      5
# 5      6
# 6      2
# Name: name, dtype: int64

# %% [markdown]
# ## Multivariate analysis

# %%
t3.fare.describe()
# Out:
# count    1045.000000
# mean       36.686080
# std        55.732533
# min         0.000000
# 25%         8.050000
# 50%        15.750000
# 75%        35.500000
# max       512.329200
# Name: fare, dtype: float64

# %%
t3['relations'] = 0
t3.loc[t3['parch'] > 0, 'relations'] = 1
t3.loc[t3['sibsp'] > 0, 'relations'] = 1
# Out:
# /home/srivallabha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/srivallabha/.local/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
t3.relations.sum()
# Out:
# 456

# %%
print (t3.groupby(['relations', 'survived'])['name'].count())
# Out:
# relations  survived
# 0          0           401
#            1           188
# 1          0           217
#            1           239
# Name: name, dtype: int64

# %%
t31 = t3.groupby(['relations', 'survived'])['name'].count().unstack().plot(kind='bar', stacked=True)
plt.xlabel('relations')
# Out:
# Text(0.5, 0, 'relations')

# %%
t3.groupby(['pclass', 'survived'])['name'].count().unstack().plot(kind='bar', stacked=True)
plt.show()

# %%
t3.groupby(['agebins', 'survived'])['name'].count().unstack().plot(kind='bar', stacked=True)
plt.show()

# %%
farebins = pd.IntervalIndex.from_tuples([(0, 10), (10, 30), (30, 100), (100, 800)])
t3['farebins'] = pd.cut(t3['fare'], farebins)
# Out:
# /home/srivallabha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
t3.groupby(['farebins', 'survived'])['name'].count().unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# ## Building a simple model

# %%
t3.to_csv('ModelingDataTitanic.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
#t3t = t3.drop(['survived', 'agebins', 'farebins', 'name', ''], axis=1)
t3t = t3[['pclass', 'sibsp', 'fare', 'relations', 'sex', 'parch', 'agebins', 'farebins']]

# %%
t3t.head()
# Out:
#    pclass  sibsp      fare  relations     sex  parch   agebins    farebins
# 0       1      0  211.3375          0  female      0  (20, 40]  (100, 800]
# 1       1      1  151.5500          1    male      2   (0, 20]  (100, 800]
# 2       1      1  151.5500          1  female      2   (0, 20]  (100, 800]
# 3       1      1  151.5500          1    male      2  (20, 40]  (100, 800]
# 4       1      1  151.5500          1  female      2  (20, 40]  (100, 800]

# %%
def ttsplit(features):
    feats = t3t[features]
    idvs = pd.get_dummies(feats)
    X_train, X_test, y_train, y_test = train_test_split(idvs, t3['survived'], test_size=0.33, random_state=42)
    return (X_train, X_test, y_train, y_test)
    

def svc_model(features):
    X_train, X_test, y_train, y_test = ttsplit(features)
    clf = SVC(gamma='auto')
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    return (score)

# %%
f = ['pclass']
print (svc_model(f))
# Out:
# 0.663768115942029

# %%
f = ['pclass', 'sex']
print (svc_model(f))
# Out:
# 0.7391304347826086

# %%
f = ['pclass', 'sex', 'sibsp']
print (svc_model(f))
# Out:
# 0.744927536231884

# %%
f = ['pclass', 'sex', 'sibsp', 'parch']
print (svc_model(f))
# Out:
# 0.744927536231884

# %%
f = ['pclass', 'sex', 'sibsp', 'parch', 'relations']
print (svc_model(f))

# %%
f = ['pclass', 'sex', 'sibsp', 'parch', 'relations', 'agebins']
print (svc_model(f))

# %%
f = ['pclass', 'sex', 'sibsp', 'parch', 'relations', 'agebins', 'farebins']
print (svc_model(f))

# %% [markdown]
# ## Training another model  - Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
def knnmodel(features):
    X_train, X_test, y_train, y_test = ttsplit(features)
    neigh = KNeighborsClassifier(n_neighbors=15)    
    neigh.fit(X_train, y_train)
    y_pred = neigh.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    return (score)

# %%
f = ['pclass', 'sex', 'sibsp', 'parch', 'relations', 'agebins', 'farebins']
print (knnmodel(f))

# %% [markdown]
# ## Training another model - Random forest

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

def treemodel(features):
    X_train, X_test, y_train, y_test = ttsplit(features)
    clf = DecisionTreeClassifier(random_state=0)
    print (cross_val_score(clf, X_train, y_train, cv=10))
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    return (score)

# %%
treemodel(f)
