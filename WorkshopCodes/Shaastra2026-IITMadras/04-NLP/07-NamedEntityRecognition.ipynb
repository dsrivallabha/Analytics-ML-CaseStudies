# %%
import pandas as pd
import spacy
from spacy import displacy
import matplotlib.pyplot as plt
from pyvis.network import Network

# %%
# pip install networkx pyvis

# %% [markdown]
# # 01 - Load Data

# %%
# data source: Kaggle - https://www.kaggle.com/datasets/naseralqaydeh/named-entity-recognition-ner-corpus
df = pd.read_csv("../Data/ner.csv")
df.head()
# Out:
#     Sentence #                                           Sentence  \
# 0  Sentence: 1  Thousands of demonstrators have marched throug...
# 1  Sentence: 2  Families of soldiers killed in the conflict jo...
# 2  Sentence: 3  They marched from the Houses of Parliament to ...
# 3  Sentence: 4  Police put the number of marchers at 10,000 wh...
# 4  Sentence: 5  The protest comes on the eve of the annual con...
#
#                                                  POS  \
# 0  ['NNS', 'IN', 'NNS', 'VBP', 'VBN', 'IN', 'NNP'...
# 1  ['NNS', 'IN', 'NNS', 'VBN', 'IN', 'DT', 'NN', ...
# 2  ['PRP', 'VBD', 'IN', 'DT', 'NNS', 'IN', 'NN', ...
# 3  ['NNS', 'VBD', 'DT', 'NN', 'IN', 'NNS', 'IN', ...
# 4  ['DT', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'IN', 'D...
#
#                                                  Tag
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', '...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...

# %%
# Load spaCy's pre-trained English model
nlp = spacy.load("en_core_web_sm")

# Function to extract named entities from a text
def extract_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# %%
df100 = df.head(100)

# %%
# Apply NER on the text column
df100['entities'] = df100['Sentence'].apply(extract_entities)

# Save the results to a new CSV
df100.to_csv("data_with_entities.csv", index=False)

print("NER extraction completed. Results saved to 'data_with_entities.csv'.")
# Out:
# NER extraction completed. Results saved to 'data_with_entities.csv'.
# /tmp/ipykernel_64455/3255901675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df100['entities'] = df100['Sentence'].apply(extract_entities)

# %%
df100.head()
# Out:
#     Sentence #                                           Sentence  \
# 0  Sentence: 1  Thousands of demonstrators have marched throug...
# 1  Sentence: 2  Families of soldiers killed in the conflict jo...
# 2  Sentence: 3  They marched from the Houses of Parliament to ...
# 3  Sentence: 4  Police put the number of marchers at 10,000 wh...
# 4  Sentence: 5  The protest comes on the eve of the annual con...
#
#                                                  POS  \
# 0  ['NNS', 'IN', 'NNS', 'VBP', 'VBN', 'IN', 'NNP'...
# 1  ['NNS', 'IN', 'NNS', 'VBN', 'IN', 'DT', 'NN', ...
# 2  ['PRP', 'VBD', 'IN', 'DT', 'NNS', 'IN', 'NN', ...
# 3  ['NNS', 'VBD', 'DT', 'NN', 'IN', 'NNS', 'IN', ...
# 4  ['DT', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'IN', 'D...
#
#                                                  Tag  \
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', '...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
#
#                                             entities
# 0  [(Thousands, CARDINAL), (London, GPE), (Iraq, ...
# 1                 [(Stop the Bombings, WORK_OF_ART)]
# 2  [(the Houses of Parliament, ORG), (Hyde Park, ...
# 3         [(10,000, CARDINAL), (1,00,000, CARDINAL)]
# 4  [(annual, DATE), (Britain, GPE), (Labor Party,...

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Look at most common types of entities

# %%
ent_dict = {}
label_dict = {}
label_ent_dict = {}
for i in range(len(df100)):
    entlist = df100['entities'].iloc[i]
    for ent in entlist:
        if ent in ent_dict.keys():
            ent_dict[ent] += 1
        else:
            ent_dict[ent] = 1
        nent, label = ent
        if label in label_dict.keys():
            label_dict[label] += 1
        else:
            label_dict[label] = 1
        if label in label_ent_dict.keys():
            label_ent_dict[label].append(nent)
        else:
            label_ent_dict[label] = [nent]

for k in label_ent_dict.keys():
    label_ent_dict[k] = set(label_ent_dict[k])

# %%
# One sample entry
df100['entities'].iloc[99]
# Out:
# [('Saturday', 'DATE'),
#  ('Orakzai', 'PERSON'),
#  ('Taliban', 'ORG'),
#  ('South Waziristan', 'GPE')]

# %%
# Count word-label frequencies
{w:ent_dict[w] for w in sorted(ent_dict, key=ent_dict.get, reverse=True)}
# Out:
# {('Wednesday', 'DATE'): 6,
#  ('Iran', 'GPE'): 6,
#  ('Iraq', 'GPE'): 5,
#  ('annual', 'DATE'): 5,
#  ('Mogadishu', 'GPE'): 5,
#  ('Saturday', 'DATE'): 5,
#  ('Pakistani', 'NORP'): 5,
#  ('APEC', 'ORG'): 5,
#  ('U.S.', 'GPE'): 4,
#  ('one', 'CARDINAL'): 4,
#  ('Sunday', 'DATE'): 4,
#  ('Pakistan', 'GPE'): 4,
#  ('three', 'CARDINAL'): 4,
#  ('British', 'NORP'): 3,
#  ('last week', 'DATE'): 3,
#  ('Baghdad', 'GPE'): 3,
#  ('Taleban', 'NORP'): 3,
#  ('Afghanistan', 'GPE'): 3,
#  ('South Waziristan', 'GPE'): 3,
#  ('Halliburton', 'GPE'): 3,
#  ('ABAC', 'ORG'): 3,
#  ('Sudanese', 'NORP'): 3,
#  ('Indonesian', 'NORP'): 3,
#  ('Bali', 'GPE'): 3,
#  ('London', 'GPE'): 2,
#  ('Britain', 'GPE'): 2,
#  ('Rome', 'GPE'): 2,
#  ('this week', 'DATE'): 2,
#  ('Iranian', 'NORP'): 2,
#  ('Tuesday', 'DATE'): 2,
#  ('Two', 'CARDINAL'): 2,
#  ('Nigeria', 'GPE'): 2,
#  ('German', 'NORP'): 2,
#  ('Somalia', 'GPE'): 2,
#  ('Mosul', 'GPE'): 2,
#  ('al Qaida', 'ORG'): 2,
#  ('more than 200', 'CARDINAL'): 2,
#  ('American', 'NORP'): 2,
#  ('Friday', 'DATE'): 2,
#  ('Brotherhood', 'ORG'): 2,
#  ('The Muslim Brotherhood', 'ORG'): 2,
#  ('Islamic', 'NORP'): 2,
#  ('Khayam', 'ORG'): 2,
#  ('the Australian Trade Commission', 'ORG'): 2,
#  ('Harcourt', 'ORG'): 2,
#  ('Darfur', 'GPE'): 2,
#  ('April', 'DATE'): 2,
#  ('South Darfur', 'GPE'): 2,
#  ('Azahari bin Husin', 'PERSON'): 2,
#  ('Muslims', 'NORP'): 2,
#  ('Thousands', 'CARDINAL'): 1,
#  ('Stop the Bombings', 'WORK_OF_ART'): 1,
#  ('the Houses of Parliament', 'ORG'): 1,
#  ('Hyde Park', 'GPE'): 1,
#  ('10,000', 'CARDINAL'): 1,
#  ('1,00,000', 'CARDINAL'): 1,
#  ('Labor Party', 'ORG'): 1,
#  ('English', 'LANGUAGE'): 1,
#  ('Brighton', 'GPE'): 1,
#  ('8,500', 'CARDINAL'): 1,
#  ('today', 'DATE'): 1,
#  ('Paris', 'GPE'): 1,
#  ('Madrid', 'GPE'): 1,
#  ('The International Atomic Energy Agency', 'ORG'): 1,
#  ('second', 'ORDINAL'): 1,
#  ('Vienna', 'GPE'): 1,
#  ('Isfahan', 'FAC'): 1,
#  ('IAEA', 'ORG'): 1,
#  ('The European Union', 'ORG'): 1,
#  ('the U.N. Security Council', 'ORG'): 1,
#  ('Tehran', 'GPE'): 1,
#  ('the Nuclear Non-Proliferation', 'ORG'): 1,
#  ('Mahmoud Ahmadinejad', 'PERSON'): 1,
#  ('European', 'NORP'): 1,
#  ('Germans', 'NORP'): 1,
#  ('four', 'CARDINAL'): 1,
#  ('Nigerian', 'NORP'): 1,
#  ('Delta', 'LOC'): 1,
#  ('Bilfinger Berger', 'PERSON'): 1,
#  ('Thomas Horbach', 'PERSON'): 1,
#  ('Delta State', 'ORG'): 1,
#  ('Bayelsa State', 'PERSON'): 1,
#  ('Royal-Dutch Shell', 'ORG'): 1,
#  ('Shell', 'ORG'): 1,
#  ('the Niger Delta', 'LOC'): 1,
#  ('2.3 million barrels', 'QUANTITY'): 1,
#  ('daily', 'DATE'): 1,
#  ('Suspected Islamist', 'NORP'): 1,
#  ('Abdullahi Yusuf Ahmad', 'PERSON'): 1,
#  ('at least five', 'CARDINAL'): 1,
#  ('more than 1,300', 'CARDINAL'): 1,
#  ('Somali', 'NORP'): 1,
#  ('Iraqi', 'NORP'): 1,
#  ('Sunni Arab', 'NORP'): 1,
#  ('Kurdish', 'NORP'): 1,
#  ('at least 34', 'CARDINAL'): 1,
#  ('Anbar', 'GPE'): 1,
#  ('Sunni', 'NORP'): 1,
#  ('Egyptian', 'NORP'): 1,
#  ('at least 16', 'CARDINAL'): 1,
#  ('Muslim Brotherhood', 'ORG'): 1,
#  ('Alexandria', 'GPE'): 1,
#  ('47', 'CARDINAL'): 1,
#  ('nine', 'CARDINAL'): 1,
#  ('Hardline', 'NORP'): 1,
#  ('North West', 'LOC'): 1,
#  ('six', 'CARDINAL'): 1,
#  ('Thursday', 'DATE'): 1,
#  ('68-34', 'CARDINAL'): 1,
#  ('weekly', 'DATE'): 1,
#  ('up to six months', 'DATE'): 1,
#  ('Islam', 'ORG'): 1,
#  ('Prophet Muhammad', 'PERSON'): 1,
#  ('Omar Khayam', 'PERSON'): 1,
#  ('Bedford', 'GPE'): 1,
#  ('the British Home Office', 'ORG'): 1,
#  ('Home Office', 'ORG'): 1,
#  ('the Associated Press', 'ORG'): 1,
#  ('AP', 'ORG'): 1,
#  ('last year', 'DATE'): 1,
#  ('half', 'CARDINAL'): 1,
#  ('six-year', 'DATE'): 1,
#  ('Malik Faridullah Khan', 'PERSON'): 1,
#  ('a day', 'DATE'): 1,
#  ('al-Qaida', 'ORG'): 1,
#  ('2001', 'DATE'): 1,
#  ('the United States', 'GPE'): 1,
#  ('Abdul Qadeer Khan', 'PERSON'): 1,
#  ('Libya', 'GPE'): 1,
#  ('North Korea', 'GPE'): 1,
#  ('Washington', 'GPE'): 1,
#  ('Khan', 'PERSON'): 1,
#  ('2004', 'DATE'): 1,
#  ('Islamabad', 'GPE'): 1,
#  ('U.S. Army', 'ORG'): 1,
#  ('multi-billion dollar', 'MONEY'): 1,
#  ('several years', 'DATE'): 1,
#  ('Democrats', 'NORP'): 1,
#  ('the Asia Pacific Economic Cooperation Business Advisory Council', 'ORG'): 1,
#  ('September 8 and 9', 'DATE'): 1,
#  ('VOA', 'ORG'): 1,
#  ('Nancy-Amelia Collins', 'ORG'): 1,
#  ('Sydney', 'GPE'): 1,
#  ("the World Trade Organization 's", 'ORG'): 1,
#  ('the APEC Business Advisory Council', 'ORG'): 1,
#  ('Tim Harcourt', 'PERSON'): 1,
#  ('21', 'CARDINAL'): 1,
#  ('1995', 'DATE'): 1,
#  ('Sudan', 'GPE'): 1,
#  ('Mustafa Osman Ismail', 'PERSON'): 1,
#  ('Ismail', 'PERSON'): 1,
#  ('the United Nations', 'ORG'): 1,
#  ('African Union', 'ORG'): 1,
#  ('Khartoum', 'GPE'): 1,
#  ('recent weeks', 'DATE'): 1,
#  ('AU', 'ORG'): 1,
#  ('AU', 'NORP'): 1,
#  ('Labado', 'GPE'): 1,
#  ('Khartoum', 'PERSON'): 1,
#  ('October 1', 'DATE'): 1,
#  ('Bali', 'PERSON'): 1,
#  ('23', 'CARDINAL'): 1,
#  ('Java', 'PERSON'): 1,
#  ('Australian', 'NORP'): 1,
#  ('French', 'NORP'): 1,
#  ('at least one', 'CARDINAL'): 1,
#  ('Indonesia', 'GPE'): 1,
#  ("last month 's", 'DATE'): 1,
#  ('2002', 'DATE'): 1,
#  ('Roman Catholic', 'NORP'): 1,
#  ('Islamist', 'NORP'): 1,
#  ('Muslim', 'NORP'): 1,
#  ('Benedict', 'PERSON'): 1,
#  ('Sister Leonella Sgorbati', 'ORG'): 1,
#  ('Vatican', 'ORG'): 1,
#  ('14 century', 'DATE'): 1,
#  ('Byzantine', 'NORP'): 1,
#  ('a third day', 'DATE'): 1,
#  ('at least nine', 'CARDINAL'): 1,
#  ('Orakzai', 'PERSON'): 1,
#  ('Taliban', 'ORG'): 1}

# %%
# Count label frequencies
{w:label_dict[w] for w in sorted(label_dict, key=label_dict.get, reverse=True)}
# Out:
# {'GPE': 74,
#  'DATE': 50,
#  'ORG': 49,
#  'NORP': 46,
#  'CARDINAL': 30,
#  'PERSON': 20,
#  'LOC': 3,
#  'WORK_OF_ART': 1,
#  'LANGUAGE': 1,
#  'ORDINAL': 1,
#  'FAC': 1,
#  'QUANTITY': 1,
#  'MONEY': 1}

# %%
label_ent_dict
# Out:
# {'CARDINAL': {'1,00,000',
#   '10,000',
#   '21',
#   '23',
#   '47',
#   '68-34',
#   '8,500',
#   'Thousands',
#   'Two',
#   'at least 16',
#   'at least 34',
#   'at least five',
#   'at least nine',
#   'at least one',
#   'four',
#   'half',
#   'more than 1,300',
#   'more than 200',
#   'nine',
#   'one',
#   'six',
#   'three'},
#  'GPE': {'Afghanistan',
#   'Alexandria',
#   'Anbar',
#   'Baghdad',
#   'Bali',
#   'Bedford',
#   'Brighton',
#   'Britain',
#   'Darfur',
#   'Halliburton',
#   'Hyde Park',
#   'Indonesia',
#   'Iran',
#   'Iraq',
#   'Islamabad',
#   'Khartoum',
#   'Labado',
#   'Libya',
#   'London',
#   'Madrid',
#   'Mogadishu',
#   'Mosul',
#   'Nigeria',
#   'North Korea',
#   'Pakistan',
#   'Paris',
#   'Rome',
#   'Somalia',
#   'South Darfur',
#   'South Waziristan',
#   'Sudan',
#   'Sydney',
#   'Tehran',
#   'U.S.',
#   'Vienna',
#   'Washington',
#   'the United States'},
#  'NORP': {'AU',
#   'American',
#   'Australian',
#   'British',
#   'Byzantine',
#   'Democrats',
#   'Egyptian',
#   'European',
#   'French',
#   'German',
#   'Germans',
#   'Hardline',
#   'Indonesian',
#   'Iranian',
#   'Iraqi',
#   'Islamic',
#   'Islamist',
#   'Kurdish',
#   'Muslim',
#   'Muslims',
#   'Nigerian',
#   'Pakistani',
#   'Roman Catholic',
#   'Somali',
#   'Sudanese',
#   'Sunni',
#   'Sunni Arab',
#   'Suspected Islamist',
#   'Taleban'},
#  'WORK_OF_ART': {'Stop the Bombings'},
#  'ORG': {'ABAC',
#   'AP',
#   'APEC',
#   'AU',
#   'African Union',
#   'Brotherhood',
#   'Delta State',
#   'Harcourt',
#   'Home Office',
#   'IAEA',
#   'Islam',
#   'Khayam',
#   'Labor Party',
#   'Muslim Brotherhood',
#   'Nancy-Amelia Collins',
#   'Royal-Dutch Shell',
#   'Shell',
#   'Sister Leonella Sgorbati',
#   'Taliban',
#   'The European Union',
#   'The International Atomic Energy Agency',
#   'The Muslim Brotherhood',
#   'U.S. Army',
#   'VOA',
#   'Vatican',
#   'al Qaida',
#   'al-Qaida',
#   'the APEC Business Advisory Council',
#   'the Asia Pacific Economic Cooperation Business Advisory Council',
#   'the Associated Press',
#   'the Australian Trade Commission',
#   'the British Home Office',
#   'the Houses of Parliament',
#   'the Nuclear Non-Proliferation',
#   'the U.N. Security Council',
#   'the United Nations',
#   "the World Trade Organization 's"},
#  'DATE': {'14 century',
#   '1995',
#   '2001',
#   '2002',
#   '2004',
#   'April',
#   'Friday',
#   'October 1',
#   'Saturday',
#   'September 8 and 9',
#   'Sunday',
#   'Thursday',
#   'Tuesday',
#   'Wednesday',
#   'a day',
#   'a third day',
#   'annual',
#   'daily',
#   "last month 's",
#   'last week',
#   'last year',
#   'recent weeks',
#   'several years',
#   'six-year',
#   'this week',
#   'today',
#   'up to six months',
#   'weekly'},
#  'LANGUAGE': {'English'},
#  'ORDINAL': {'second'},
#  'FAC': {'Isfahan'},
#  'PERSON': {'Abdul Qadeer Khan',
#   'Abdullahi Yusuf Ahmad',
#   'Azahari bin Husin',
#   'Bali',
#   'Bayelsa State',
#   'Benedict',
#   'Bilfinger Berger',
#   'Ismail',
#   'Java',
#   'Khan',
#   'Khartoum',
#   'Mahmoud Ahmadinejad',
#   'Malik Faridullah Khan',
#   'Mustafa Osman Ismail',
#   'Omar Khayam',
#   'Orakzai',
#   'Prophet Muhammad',
#   'Thomas Horbach',
#   'Tim Harcourt'},
#  'LOC': {'Delta', 'North West', 'the Niger Delta'},
#  'QUANTITY': {'2.3 million barrels'},
#  'MONEY': {'multi-billion dollar'}}

# %% [markdown]
# # Display Entities

# %%
# Display entities
text = df100['Sentence'].iloc[0]
doc = nlp(text)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of demonstrators have marched through
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to protest the war in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iraq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and demand the withdrawal of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  troops from that country .</div></span>

# %%
# Get relations between labels
label_list = []
for i in range(len(df100)):
    entlist = df100['entities'].iloc[i]
    label_ll = []
    for ent in entlist:
        nent, label = ent
        label_ll.append(label)
    label_list.append(label_ll)

# %%
label_list
# Out:
# [['CARDINAL', 'GPE', 'GPE', 'NORP'],
#  ['WORK_OF_ART'],
#  ['ORG', 'GPE'],
#  ['CARDINAL', 'CARDINAL'],
#  ['DATE', 'GPE', 'ORG', 'LANGUAGE', 'GPE'],
#  ['GPE', 'GPE', 'CARDINAL', 'NORP'],
#  ['GPE', 'DATE', 'GPE', 'GPE', 'GPE'],
#  ['ORG', 'ORDINAL', 'GPE', 'DATE', 'GPE'],
#  ['GPE', 'DATE', 'FAC'],
#  ['NORP', 'DATE', 'ORG'],
#  [],
#  ['ORG', 'GPE', 'GPE', 'ORG', 'GPE', 'ORG'],
#  ['GPE', 'PERSON', 'DATE', 'NORP', 'GPE', 'NORP'],
#  ['CARDINAL', 'NORP', 'CARDINAL', 'NORP', 'GPE', 'LOC'],
#  ['NORP', 'PERSON', 'PERSON', 'DATE', 'ORG', 'PERSON', 'ORG'],
#  ['NORP', 'ORG'],
#  ['LOC'],
#  ['GPE', 'QUANTITY', 'DATE'],
#  ['NORP', 'GPE', 'PERSON'],
#  ['GPE'],
#  ['CARDINAL', 'GPE', 'DATE'],
#  ['CARDINAL', 'NORP'],
#  ['NORP', 'GPE', 'ORG', 'GPE'],
#  ['NORP', 'NORP', 'DATE', 'CARDINAL', 'CARDINAL'],
#  ['GPE', 'NORP'],
#  ['ORG', 'GPE', 'GPE', 'GPE'],
#  ['GPE', 'GPE', 'NORP'],
#  ['GPE', 'CARDINAL', 'NORP', 'GPE', 'DATE'],
#  ['NORP', 'CARDINAL', 'ORG', 'DATE'],
#  ['DATE', 'GPE'],
#  ['ORG', 'ORG'],
#  ['ORG', 'CARDINAL'],
#  ['DATE', 'CARDINAL'],
#  ['ORG'],
#  ['NORP', 'GPE', 'LOC', 'NORP'],
#  ['CARDINAL', 'DATE', 'CARDINAL'],
#  [],
#  ['NORP', 'DATE', 'DATE'],
#  ['DATE'],
#  ['NORP', 'GPE'],
#  ['NORP', 'ORG', 'PERSON'],
#  ['DATE', 'PERSON', 'GPE'],
#  ['ORG', 'ORG', 'DATE'],
#  ['ORG', 'ORG'],
#  ['ORG', 'ORG', 'DATE', 'CARDINAL', 'DATE'],
#  ['NORP', 'CARDINAL', 'GPE'],
#  ['PERSON', 'GPE', 'DATE'],
#  [],
#  [],
#  ['DATE', 'NORP', 'GPE'],
#  ['ORG', 'NORP', 'NORP', 'GPE', 'DATE'],
#  ['NORP', 'GPE', 'CARDINAL', 'GPE'],
#  ['GPE', 'PERSON', 'GPE', 'GPE', 'GPE'],
#  [],
#  ['NORP', 'GPE'],
#  ['PERSON', 'DATE'],
#  ['GPE', 'GPE'],
#  ['ORG', 'DATE', 'MONEY', 'GPE', 'GPE', 'GPE'],
#  ['GPE', 'DATE'],
#  ['GPE', 'NORP'],
#  [],
#  [],
#  [],
#  ['ORG', 'DATE', 'DATE', 'ORG', 'DATE'],
#  ['ORG', 'ORG', 'GPE'],
#  ['ORG', 'DATE', 'ORG', 'ORG'],
#  ['PERSON', 'ORG'],
#  ['ORG'],
#  ['ORG'],
#  ['CARDINAL', 'CARDINAL', 'ORG'],
#  ['CARDINAL'],
#  ['DATE', 'ORG'],
#  [],
#  ['DATE'],
#  ['ORG', 'ORG'],
#  ['ORG'],
#  ['CARDINAL'],
#  ['ORG'],
#  ['DATE', 'ORG', 'DATE'],
#  ['GPE', 'GPE'],
#  ['PERSON', 'NORP', 'DATE'],
#  ['PERSON', 'ORG', 'ORG', 'GPE', 'DATE'],
#  ['DATE', 'ORG', 'NORP', 'DATE'],
#  ['DATE', 'NORP', 'GPE', 'NORP', 'GPE', 'GPE'],
#  ['PERSON'],
#  ['GPE'],
#  ['NORP', 'CARDINAL', 'DATE', 'PERSON', 'CARDINAL'],
#  ['NORP', 'DATE', 'GPE', 'PERSON', 'GPE'],
#  ['NORP', 'NORP', 'CARDINAL', 'DATE', 'GPE'],
#  ['PERSON'],
#  ['NORP', 'PERSON', 'DATE', 'GPE', 'DATE', 'CARDINAL'],
#  ['NORP', 'NORP', 'GPE', 'GPE'],
#  ['DATE', 'NORP', 'PERSON'],
#  ['CARDINAL', 'ORG', 'GPE'],
#  ['CARDINAL'],
#  ['GPE', 'ORG', 'NORP'],
#  ['GPE'],
#  ['NORP', 'DATE', 'NORP'],
#  ['NORP', 'DATE', 'CARDINAL'],
#  ['DATE', 'PERSON', 'ORG', 'GPE']]

# %%
from itertools import combinations 

def item_pairs(inp_list):
    return list(combinations(sorted(inp_list), 2))    

A = ['cat', 'baby', 'apple']
item_pairs(A)
# Out:
# [('apple', 'baby'), ('apple', 'cat'), ('baby', 'cat')]

# %%
label_pairs= {}
for ll in label_list:
    pairs = item_pairs(ll)
    for pp in pairs:
        if pp in label_pairs.keys():
            label_pairs[pp] += 1
        else:
            label_pairs[pp] = 1

{w:label_pairs[w] for w in sorted(label_pairs, key = label_pairs.get, reverse=True)}
# Out:
# {('GPE', 'NORP'): 45,
#  ('GPE', 'GPE'): 37,
#  ('DATE', 'GPE'): 34,
#  ('DATE', 'ORG'): 31,
#  ('GPE', 'ORG'): 30,
#  ('DATE', 'NORP'): 28,
#  ('CARDINAL', 'NORP'): 21,
#  ('CARDINAL', 'DATE'): 16,
#  ('CARDINAL', 'GPE'): 15,
#  ('ORG', 'ORG'): 15,
#  ('DATE', 'PERSON'): 15,
#  ('GPE', 'PERSON'): 14,
#  ('NORP', 'PERSON'): 12,
#  ('NORP', 'ORG'): 11,
#  ('ORG', 'PERSON'): 11,
#  ('NORP', 'NORP'): 9,
#  ('DATE', 'DATE'): 8,
#  ('CARDINAL', 'ORG'): 7,
#  ('CARDINAL', 'CARDINAL'): 6,
#  ('LOC', 'NORP'): 4,
#  ('PERSON', 'PERSON'): 3,
#  ('GPE', 'MONEY'): 3,
#  ('CARDINAL', 'PERSON'): 3,
#  ('GPE', 'LANGUAGE'): 2,
#  ('GPE', 'ORDINAL'): 2,
#  ('CARDINAL', 'LOC'): 2,
#  ('GPE', 'LOC'): 2,
#  ('DATE', 'LANGUAGE'): 1,
#  ('LANGUAGE', 'ORG'): 1,
#  ('DATE', 'ORDINAL'): 1,
#  ('ORDINAL', 'ORG'): 1,
#  ('DATE', 'FAC'): 1,
#  ('FAC', 'GPE'): 1,
#  ('DATE', 'QUANTITY'): 1,
#  ('GPE', 'QUANTITY'): 1,
#  ('DATE', 'MONEY'): 1,
#  ('MONEY', 'ORG'): 1}

# %%
# Get relations between entities
entity_list = []
for i in range(len(df100)):
    entlist = df100['entities'].iloc[i]
    ent_ll = []
    for ent in entlist:
        nent, label = ent
        if label not in ['CARDINAL', 'DATE']:
            ent_ll.append(nent)
    entity_list.append(ent_ll)

entity_list
# Out:
# [['London', 'Iraq', 'British'],
#  ['Stop the Bombings'],
#  ['the Houses of Parliament', 'Hyde Park'],
#  [],
#  ['Britain', 'Labor Party', 'English', 'Brighton'],
#  ['Britain', 'Iraq', 'British'],
#  ['London', 'Rome', 'Paris', 'Madrid'],
#  ['The International Atomic Energy Agency', 'second', 'Vienna', 'Iran'],
#  ['Iran', 'Isfahan'],
#  ['Iranian', 'IAEA'],
#  [],
#  ['The European Union',
#   'U.S.',
#   'Iran',
#   'the U.N. Security Council',
#   'Tehran',
#   'the Nuclear Non-Proliferation'],
#  ['Iran', 'Mahmoud Ahmadinejad', 'European', 'Iran', 'Iranian'],
#  ['Germans', 'Nigerian', 'Nigeria', 'Delta'],
#  ['German',
#   'Bilfinger Berger',
#   'Thomas Horbach',
#   'Delta State',
#   'Bayelsa State',
#   'Royal-Dutch Shell'],
#  ['German', 'Shell'],
#  ['the Niger Delta'],
#  ['Nigeria', '2.3 million barrels'],
#  ['Suspected Islamist', 'Somalia', 'Abdullahi Yusuf Ahmad'],
#  ['Mogadishu'],
#  ['Mogadishu'],
#  ['Somali'],
#  ['Iraqi', 'Mosul', 'al Qaida', 'Iraq'],
#  ['Sunni Arab', 'Kurdish'],
#  ['U.S.', 'American'],
#  ['al Qaida', 'Iraq', 'Anbar', 'Baghdad'],
#  ['Mosul', 'Baghdad', 'Sunni'],
#  ['U.S.', 'American', 'Baghdad'],
#  ['Egyptian', 'Muslim Brotherhood'],
#  ['Alexandria'],
#  ['Brotherhood', 'Brotherhood'],
#  ['The Muslim Brotherhood'],
#  [],
#  ['The Muslim Brotherhood'],
#  ['Hardline', 'Pakistan', 'North West', 'Islamic'],
#  [],
#  [],
#  ['Islamic'],
#  [],
#  ['Taleban', 'Afghanistan'],
#  ['British', 'Islam', 'Prophet Muhammad'],
#  ['Omar Khayam', 'Bedford'],
#  ['the British Home Office', 'Khayam'],
#  ['Home Office', 'the Associated Press'],
#  ['AP', 'Khayam'],
#  ['Pakistani', 'Afghanistan'],
#  ['Malik Faridullah Khan', 'South Waziristan'],
#  [],
#  [],
#  ['Pakistani', 'South Waziristan'],
#  ['al-Qaida', 'Taleban', 'Taleban', 'Afghanistan'],
#  ['Pakistani', 'Pakistan', 'the United States'],
#  ['Pakistan', 'Abdul Qadeer Khan', 'Iran', 'Libya', 'North Korea'],
#  [],
#  ['Pakistani', 'Washington'],
#  ['Khan'],
#  ['Islamabad', 'Pakistan'],
#  ['U.S. Army', 'multi-billion dollar', 'Halliburton', 'U.S.', 'Iraq'],
#  ['Halliburton'],
#  ['Halliburton', 'Democrats'],
#  [],
#  [],
#  [],
#  ['the Asia Pacific Economic Cooperation Business Advisory Council', 'APEC'],
#  ['VOA', 'Nancy-Amelia Collins', 'Sydney'],
#  ["the World Trade Organization 's",
#   'the APEC Business Advisory Council',
#   'ABAC'],
#  ['Tim Harcourt', 'the Australian Trade Commission'],
#  ['Harcourt'],
#  ['ABAC'],
#  ['APEC'],
#  [],
#  ['APEC'],
#  [],
#  [],
#  ['the Australian Trade Commission', 'ABAC'],
#  ['Harcourt'],
#  [],
#  ['APEC'],
#  ['APEC'],
#  ['Sudan', 'Darfur'],
#  ['Mustafa Osman Ismail', 'Sudanese'],
#  ['Ismail', 'the United Nations', 'African Union', 'Khartoum'],
#  ['AU', 'Sudanese'],
#  ['AU', 'Darfur', 'Sudanese', 'South Darfur', 'Labado'],
#  ['Khartoum'],
#  ['South Darfur'],
#  ['Indonesian', 'Bali'],
#  ['Indonesian', 'Bali', 'Java', 'Bali'],
#  ['Australian', 'French', 'Indonesia'],
#  ['Azahari bin Husin'],
#  ['Indonesian', 'Azahari bin Husin', 'Bali'],
#  ['Roman Catholic', 'Islamist', 'Mogadishu', 'Somalia'],
#  ['Muslim', 'Benedict'],
#  ['Sister Leonella Sgorbati', 'Mogadishu'],
#  [],
#  ['Rome', 'Vatican', 'Muslims'],
#  ['Mogadishu'],
#  ['Muslims', 'Byzantine'],
#  ['Pakistani'],
#  ['Orakzai', 'Taliban', 'South Waziristan']]

# %%
# Create a dictionary 
entity_pairs= {}
for ents in entity_list:
    pairs = item_pairs(ents)
    for pp in pairs:
        if pp in entity_pairs.keys():
            entity_pairs[pp] += 1
        else:
            entity_pairs[pp] = 1

{w:entity_pairs[w] for w in sorted(entity_pairs, key = entity_pairs.get, reverse=True)}
# Out:
# {('Bali', 'Indonesian'): 4,
#  ('Afghanistan', 'Taleban'): 3,
#  ('British', 'Iraq'): 2,
#  ('European', 'Iran'): 2,
#  ('Iran', 'Iranian'): 2,
#  ('Iran', 'Mahmoud Ahmadinejad'): 2,
#  ('Iraq', 'al Qaida'): 2,
#  ('American', 'U.S.'): 2,
#  ('Taleban', 'al-Qaida'): 2,
#  ('AU', 'Sudanese'): 2,
#  ('Bali', 'Java'): 2,
#  ('British', 'London'): 1,
#  ('Iraq', 'London'): 1,
#  ('Hyde Park', 'the Houses of Parliament'): 1,
#  ('Brighton', 'Britain'): 1,
#  ('Brighton', 'English'): 1,
#  ('Brighton', 'Labor Party'): 1,
#  ('Britain', 'English'): 1,
#  ('Britain', 'Labor Party'): 1,
#  ('English', 'Labor Party'): 1,
#  ('Britain', 'British'): 1,
#  ('Britain', 'Iraq'): 1,
#  ('London', 'Madrid'): 1,
#  ('London', 'Paris'): 1,
#  ('London', 'Rome'): 1,
#  ('Madrid', 'Paris'): 1,
#  ('Madrid', 'Rome'): 1,
#  ('Paris', 'Rome'): 1,
#  ('Iran', 'The International Atomic Energy Agency'): 1,
#  ('Iran', 'Vienna'): 1,
#  ('Iran', 'second'): 1,
#  ('The International Atomic Energy Agency', 'Vienna'): 1,
#  ('The International Atomic Energy Agency', 'second'): 1,
#  ('Vienna', 'second'): 1,
#  ('Iran', 'Isfahan'): 1,
#  ('IAEA', 'Iranian'): 1,
#  ('Iran', 'Tehran'): 1,
#  ('Iran', 'The European Union'): 1,
#  ('Iran', 'U.S.'): 1,
#  ('Iran', 'the Nuclear Non-Proliferation'): 1,
#  ('Iran', 'the U.N. Security Council'): 1,
#  ('Tehran', 'The European Union'): 1,
#  ('Tehran', 'U.S.'): 1,
#  ('Tehran', 'the Nuclear Non-Proliferation'): 1,
#  ('Tehran', 'the U.N. Security Council'): 1,
#  ('The European Union', 'U.S.'): 1,
#  ('The European Union', 'the Nuclear Non-Proliferation'): 1,
#  ('The European Union', 'the U.N. Security Council'): 1,
#  ('U.S.', 'the Nuclear Non-Proliferation'): 1,
#  ('U.S.', 'the U.N. Security Council'): 1,
#  ('the Nuclear Non-Proliferation', 'the U.N. Security Council'): 1,
#  ('European', 'Iranian'): 1,
#  ('European', 'Mahmoud Ahmadinejad'): 1,
#  ('Iran', 'Iran'): 1,
#  ('Iranian', 'Mahmoud Ahmadinejad'): 1,
#  ('Delta', 'Germans'): 1,
#  ('Delta', 'Nigeria'): 1,
#  ('Delta', 'Nigerian'): 1,
#  ('Germans', 'Nigeria'): 1,
#  ('Germans', 'Nigerian'): 1,
#  ('Nigeria', 'Nigerian'): 1,
#  ('Bayelsa State', 'Bilfinger Berger'): 1,
#  ('Bayelsa State', 'Delta State'): 1,
#  ('Bayelsa State', 'German'): 1,
#  ('Bayelsa State', 'Royal-Dutch Shell'): 1,
#  ('Bayelsa State', 'Thomas Horbach'): 1,
#  ('Bilfinger Berger', 'Delta State'): 1,
#  ('Bilfinger Berger', 'German'): 1,
#  ('Bilfinger Berger', 'Royal-Dutch Shell'): 1,
#  ('Bilfinger Berger', 'Thomas Horbach'): 1,
#  ('Delta State', 'German'): 1,
#  ('Delta State', 'Royal-Dutch Shell'): 1,
#  ('Delta State', 'Thomas Horbach'): 1,
#  ('German', 'Royal-Dutch Shell'): 1,
#  ('German', 'Thomas Horbach'): 1,
#  ('Royal-Dutch Shell', 'Thomas Horbach'): 1,
#  ('German', 'Shell'): 1,
#  ('2.3 million barrels', 'Nigeria'): 1,
#  ('Abdullahi Yusuf Ahmad', 'Somalia'): 1,
#  ('Abdullahi Yusuf Ahmad', 'Suspected Islamist'): 1,
#  ('Somalia', 'Suspected Islamist'): 1,
#  ('Iraq', 'Iraqi'): 1,
#  ('Iraq', 'Mosul'): 1,
#  ('Iraqi', 'Mosul'): 1,
#  ('Iraqi', 'al Qaida'): 1,
#  ('Mosul', 'al Qaida'): 1,
#  ('Kurdish', 'Sunni Arab'): 1,
#  ('Anbar', 'Baghdad'): 1,
#  ('Anbar', 'Iraq'): 1,
#  ('Anbar', 'al Qaida'): 1,
#  ('Baghdad', 'Iraq'): 1,
#  ('Baghdad', 'al Qaida'): 1,
#  ('Baghdad', 'Mosul'): 1,
#  ('Baghdad', 'Sunni'): 1,
#  ('Mosul', 'Sunni'): 1,
#  ('American', 'Baghdad'): 1,
#  ('Baghdad', 'U.S.'): 1,
#  ('Egyptian', 'Muslim Brotherhood'): 1,
#  ('Brotherhood', 'Brotherhood'): 1,
#  ('Hardline', 'Islamic'): 1,
#  ('Hardline', 'North West'): 1,
#  ('Hardline', 'Pakistan'): 1,
#  ('Islamic', 'North West'): 1,
#  ('Islamic', 'Pakistan'): 1,
#  ('North West', 'Pakistan'): 1,
#  ('British', 'Islam'): 1,
#  ('British', 'Prophet Muhammad'): 1,
#  ('Islam', 'Prophet Muhammad'): 1,
#  ('Bedford', 'Omar Khayam'): 1,
#  ('Khayam', 'the British Home Office'): 1,
#  ('Home Office', 'the Associated Press'): 1,
#  ('AP', 'Khayam'): 1,
#  ('Afghanistan', 'Pakistani'): 1,
#  ('Malik Faridullah Khan', 'South Waziristan'): 1,
#  ('Pakistani', 'South Waziristan'): 1,
#  ('Afghanistan', 'al-Qaida'): 1,
#  ('Taleban', 'Taleban'): 1,
#  ('Pakistan', 'Pakistani'): 1,
#  ('Pakistan', 'the United States'): 1,
#  ('Pakistani', 'the United States'): 1,
#  ('Abdul Qadeer Khan', 'Iran'): 1,
#  ('Abdul Qadeer Khan', 'Libya'): 1,
#  ('Abdul Qadeer Khan', 'North Korea'): 1,
#  ('Abdul Qadeer Khan', 'Pakistan'): 1,
#  ('Iran', 'Libya'): 1,
#  ('Iran', 'North Korea'): 1,
#  ('Iran', 'Pakistan'): 1,
#  ('Libya', 'North Korea'): 1,
#  ('Libya', 'Pakistan'): 1,
#  ('North Korea', 'Pakistan'): 1,
#  ('Pakistani', 'Washington'): 1,
#  ('Islamabad', 'Pakistan'): 1,
#  ('Halliburton', 'Iraq'): 1,
#  ('Halliburton', 'U.S.'): 1,
#  ('Halliburton', 'U.S. Army'): 1,
#  ('Halliburton', 'multi-billion dollar'): 1,
#  ('Iraq', 'U.S.'): 1,
#  ('Iraq', 'U.S. Army'): 1,
#  ('Iraq', 'multi-billion dollar'): 1,
#  ('U.S.', 'U.S. Army'): 1,
#  ('U.S.', 'multi-billion dollar'): 1,
#  ('U.S. Army', 'multi-billion dollar'): 1,
#  ('Democrats', 'Halliburton'): 1,
#  ('APEC',
#   'the Asia Pacific Economic Cooperation Business Advisory Council'): 1,
#  ('Nancy-Amelia Collins', 'Sydney'): 1,
#  ('Nancy-Amelia Collins', 'VOA'): 1,
#  ('Sydney', 'VOA'): 1,
#  ('ABAC', 'the APEC Business Advisory Council'): 1,
#  ('ABAC', "the World Trade Organization 's"): 1,
#  ('the APEC Business Advisory Council', "the World Trade Organization 's"): 1,
#  ('Tim Harcourt', 'the Australian Trade Commission'): 1,
#  ('ABAC', 'the Australian Trade Commission'): 1,
#  ('Darfur', 'Sudan'): 1,
#  ('Mustafa Osman Ismail', 'Sudanese'): 1,
#  ('African Union', 'Ismail'): 1,
#  ('African Union', 'Khartoum'): 1,
#  ('African Union', 'the United Nations'): 1,
#  ('Ismail', 'Khartoum'): 1,
#  ('Ismail', 'the United Nations'): 1,
#  ('Khartoum', 'the United Nations'): 1,
#  ('AU', 'Darfur'): 1,
#  ('AU', 'Labado'): 1,
#  ('AU', 'South Darfur'): 1,
#  ('Darfur', 'Labado'): 1,
#  ('Darfur', 'South Darfur'): 1,
#  ('Darfur', 'Sudanese'): 1,
#  ('Labado', 'South Darfur'): 1,
#  ('Labado', 'Sudanese'): 1,
#  ('South Darfur', 'Sudanese'): 1,
#  ('Bali', 'Bali'): 1,
#  ('Indonesian', 'Java'): 1,
#  ('Australian', 'French'): 1,
#  ('Australian', 'Indonesia'): 1,
#  ('French', 'Indonesia'): 1,
#  ('Azahari bin Husin', 'Bali'): 1,
#  ('Azahari bin Husin', 'Indonesian'): 1,
#  ('Islamist', 'Mogadishu'): 1,
#  ('Islamist', 'Roman Catholic'): 1,
#  ('Islamist', 'Somalia'): 1,
#  ('Mogadishu', 'Roman Catholic'): 1,
#  ('Mogadishu', 'Somalia'): 1,
#  ('Roman Catholic', 'Somalia'): 1,
#  ('Benedict', 'Muslim'): 1,
#  ('Mogadishu', 'Sister Leonella Sgorbati'): 1,
#  ('Muslims', 'Rome'): 1,
#  ('Muslims', 'Vatican'): 1,
#  ('Rome', 'Vatican'): 1,
#  ('Byzantine', 'Muslims'): 1,
#  ('Orakzai', 'South Waziristan'): 1,
#  ('Orakzai', 'Taliban'): 1,
#  ('South Waziristan', 'Taliban'): 1}

# %%
#net = Network()
net = Network(height="750px", width="100%", bgcolor="#ffffff", font_color="black")

for key, vals in entity_pairs.items():
    a, b = key
    net.add_node(a)
    net.add_node(b)
    net.add_edge(a, b, weight=vals)

net.show('graph.html', notebook=False)
# Out:
# graph.html

# %%
#net = Network()
net = Network(height="750px", width="100%", bgcolor="#ffffff", font_color="black")

net.add_node('Cap')
net.add_node('Cap')
net.add_node('Tap')
net.add_edge('Cap', 'Tap', weight=vals)

net.show('graphz.html', notebook=False)
# Out:
# graphz.html

# %% [markdown]
# # Draw insights about specific entities

# %%
# Q1: Do the news articles report positively about London?

# %%
# TextBlob
from textblob import TextBlob

# %%
df100['sentiment'] = df100['Sentence'].apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
# /tmp/ipykernel_64455/202829138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df100['sentiment'] = df100['Sentence'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df100.head()
# Out:
#     Sentence #                                           Sentence  \
# 0  Sentence: 1  Thousands of demonstrators have marched throug...
# 1  Sentence: 2  Families of soldiers killed in the conflict jo...
# 2  Sentence: 3  They marched from the Houses of Parliament to ...
# 3  Sentence: 4  Police put the number of marchers at 10,000 wh...
# 4  Sentence: 5  The protest comes on the eve of the annual con...
#
#                                                  POS  \
# 0  ['NNS', 'IN', 'NNS', 'VBP', 'VBN', 'IN', 'NNP'...
# 1  ['NNS', 'IN', 'NNS', 'VBN', 'IN', 'DT', 'NN', ...
# 2  ['PRP', 'VBD', 'IN', 'DT', 'NNS', 'IN', 'NN', ...
# 3  ['NNS', 'VBD', 'DT', 'NN', 'IN', 'NNS', 'IN', ...
# 4  ['DT', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'IN', 'D...
#
#                                                  Tag  \
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', '...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
#
#                                             entities  sentiment
# 0  [(Thousands, CARDINAL), (London, GPE), (Iraq, ...        0.0
# 1                 [(Stop the Bombings, WORK_OF_ART)]       -0.1
# 2  [(the Houses of Parliament, ORG), (Hyde Park, ...        0.0
# 3         [(10,000, CARDINAL), (1,00,000, CARDINAL)]        0.0
# 4  [(annual, DATE), (Britain, GPE), (Labor Party,...        0.0

# %%
dff = df100[df100['Sentence'].str.contains('Afghanistan')]

# %%
dff
# Out:
#       Sentence #                                           Sentence  \
# 39  Sentence: 40  The opposition has denounced the measure , com...
# 45  Sentence: 46  Pakistani officials say unidentified gunmen ha...
# 50  Sentence: 51  The area became a refuge for many al-Qaida and...
#
#                                                   POS  \
# 39  ['DT', 'NN', 'VBZ', 'VBN', 'DT', 'NN', ',', 'V...
# 45  ['JJ', 'NNS', 'VBP', 'JJ', 'NNS', 'VBP', 'VBN'...
# 50  ['DT', 'NN', 'VBD', 'DT', 'NN', 'IN', 'JJ', 'N...
#
#                                                   Tag  \
# 39  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 45  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '...
# 50  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-org', '...
#
#                                              entities  sentiment
# 39              [(Taleban, NORP), (Afghanistan, GPE)]        0.0
# 45  [(Pakistani, NORP), (three, CARDINAL), (Afghan...       -0.1
# 50  [(al-Qaida, ORG), (Taleban, NORP), (Taleban, N...        0.5

# %%
dff['sentiment'].describe()
# Out:
# count    3.000000
# mean     0.133333
# std      0.321455
# min     -0.100000
# 25%     -0.050000
# 50%      0.000000
# 75%      0.250000
# max      0.500000
# Name: sentiment, dtype: float64

# %%
dff = df100[df100['Sentence'].str.contains('Mogadishu')]
dff['sentiment'].describe()
# Out:
# count    5.000000
# mean    -0.028333
# std      0.094942
# min     -0.141667
# 25%     -0.100000
# 50%      0.000000
# 75%      0.000000
# max      0.100000
# Name: sentiment, dtype: float64

# %%
dff = df100[df100['Sentence'].str.contains('London')]
dff['sentiment'].describe()
# Out:
# count    2.000000
# mean    -0.062500
# std      0.088388
# min     -0.125000
# 25%     -0.093750
# 50%     -0.062500
# 75%     -0.031250
# max      0.000000
# Name: sentiment, dtype: float64
