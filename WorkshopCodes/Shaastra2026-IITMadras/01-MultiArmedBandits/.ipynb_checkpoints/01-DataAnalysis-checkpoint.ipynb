# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Analysis of data

# %%
df = pd.read_csv('AdClickInfo.csv')
df.head()
# Out:
#    Customer ID            Date Time  Ad ID Gender  Age Holiday  Working  \
# 0       129899  2024-09-01 07:03:18      5      M   20     NaN    False
# 1       121047  2024-09-01 07:07:48      3      M   50     NaN    False
# 2       133576  2024-09-01 07:12:39      2      M   47     NaN    False
# 3       112276  2024-09-01 07:13:28      4      M   45     NaN    False
# 4       102275  2024-09-01 07:20:03      3      M   29     NaN    False
#
#    probs  click
# 0   0.09      0
# 1   0.12      0
# 2   0.02      0
# 3   0.49      0
# 4   0.00      0

# %%
df.shape
# Out:
# (100000, 9)

# %% [markdown]
# ### Daily analysis of CTR

# %%
print ('starting day is', df['Date Time'].min())
print ('ending day is', df['Date Time'].max())
# Out:
# starting day is 2024-09-01 07:03:18
# ending day is 2025-11-02 21:08:49

# %%
df['Date'] = df['Date Time'].apply(lambda x: str(x)[:10])

# %%
dfdaily = df[['click', 'Date']].groupby('Date').agg(['count', 'mean']).reset_index()
dfdaily.head()
# Out:
#          Date click
#               count      mean
# 0  2024-09-01   193  0.145078
# 1  2024-09-02   238  0.218487
# 2  2024-09-03   238  0.147059
# 3  2024-09-04   238  0.189076
# 4  2024-09-05   244  0.155738

# %%
plt.plot(dfdaily['Date'], dfdaily['click']['mean'])
plt.xlim('2024-09-01', '2024-10-01')
plt.xticks(rotation=90)
plt.show()

# %%
df.loc[df['Holiday'].isna(), 'Holiday'] = "NoHoliday"
df.head()
# Out:
#    Customer ID            Date Time  Ad ID Gender  Age    Holiday  Working  \
# 0       129899  2024-09-01 07:03:18      5      M   20  NoHoliday    False
# 1       121047  2024-09-01 07:07:48      3      M   50  NoHoliday    False
# 2       133576  2024-09-01 07:12:39      2      M   47  NoHoliday    False
# 3       112276  2024-09-01 07:13:28      4      M   45  NoHoliday    False
# 4       102275  2024-09-01 07:20:03      3      M   29  NoHoliday    False
#
#    probs  click        Date
# 0   0.09      0  2024-09-01
# 1   0.12      0  2024-09-01
# 2   0.02      0  2024-09-01
# 3   0.49      0  2024-09-01
# 4   0.00      0  2024-09-01

# %%
df['Holiday'].unique()
# Out:
# array(['NoHoliday', 'Labor Day', 'Columbus Day', 'Veterans Day',
#        'Thanksgiving Day', 'Christmas Day', "New Year's Day",
#        'Martin Luther King Jr. Day', "Washington's Birthday",
#        'Memorial Day', 'Juneteenth National Independence Day',
#        'Independence Day'], dtype=object)

# %%
coll = df.columns
reqcoll = coll[[3,4,5,6]]
print (reqcoll)
# Out:
# Index(['Gender', 'Age', 'Holiday', 'Working'], dtype='object')

# %%
for c in reqcoll:
    print ('~~~~~~~~~~~~~~~~~~~~')
    print (c)
    df1 = df[[c, 'click']].groupby(c).agg(['count', 'mean']).reset_index()
    print (df1.head())
    plt.plot(df1[c],df1['click']['mean'], 'o--')
    plt.xticks(rotation=90)
    plt.xlabel(c)
    plt.ylabel('CTR')
    plt.show()
    print ('~~~~~~~~~~~~~~~~~~~~')
# Out:
# ~~~~~~~~~~~~~~~~~~~~
# Gender
#   Gender  click
#           count      mean
# 0      F  40289  0.152647
# 1      M  59711  0.173067
# ~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~
# Age
#   Age click
#       count      mean
# 0  18   849  0.220259
# 1  19  1582  0.210493
# 2  20  1627  0.214505
# 3  21  1601  0.207995
# 4  22  1909  0.192247
# ~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~
# Holiday
#                                 Holiday click
#                                         count      mean
# 0                         Christmas Day   223  0.264574
# 1                          Columbus Day   477  0.238994
# 2                      Independence Day   235  0.238298
# 3  Juneteenth National Independence Day   243  0.251029
# 4                             Labor Day   475  0.244211
# ~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~
# Working
#   Working  click
#            count      mean
# 0   False  28640  0.160649
# 1    True  71360  0.166522
# ~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Group by two features

# %%
df11 = df[['Age', 'Ad ID', 'click']].groupby(['Age', 'Ad ID']).agg(['count', 'mean']).reset_index()

# %%
df11
# Out:
#     Age Ad ID click
#               count      mean
# 0    18     1   181  0.187845
# 1    18     2   168  0.523810
# 2    18     3   147  0.081633
# 3    18     4   173  0.109827
# 4    18     5   180  0.188889
# ..   ..   ...   ...       ...
# 235  65     1    39  0.051282
# 236  65     2    23  0.217391
# 237  65     3    29  0.689655
# 238  65     4    32  0.125000
# 239  65     5    28  0.071429
#
# [240 rows x 4 columns]

# %%
for i in range(1, 6):
    df111 = df11[df11['Ad ID'] == i]
    plt.plot(df111['Age'], df111['click']['mean'])
    
plt.legend(['Ad 1', 'Ad 2', 'Ad 3', 'Ad 4', 'Ad 5'])
plt.xlabel('age')
plt.ylabel('CTR')
plt.title('CTR for different ads')
plt.show()

# %%
def retagebin(age):
  '''
  function to return age bins
  '''
  if (age < 25):
      return 1
  else:
      x = (age - 25)/5 + 2
      return int(x)

# test function
print (retagebin(37))
# Out:
# 4

# %%
df['Agebin']  = df['Age'].apply(lambda x: retagebin(x))

# %%
df.head()
# Out:
#    Customer ID            Date Time  Ad ID Gender  Age    Holiday  Working  \
# 0       129899  2024-09-01 07:03:18      5      M   20  NoHoliday    False
# 1       121047  2024-09-01 07:07:48      3      M   50  NoHoliday    False
# 2       133576  2024-09-01 07:12:39      2      M   47  NoHoliday    False
# 3       112276  2024-09-01 07:13:28      4      M   45  NoHoliday    False
# 4       102275  2024-09-01 07:20:03      3      M   29  NoHoliday    False
#
#    probs  click        Date  Agebin
# 0   0.09      0  2024-09-01       1
# 1   0.12      0  2024-09-01       7
# 2   0.02      0  2024-09-01       6
# 3   0.49      0  2024-09-01       6
# 4   0.00      0  2024-09-01       2

# %%
df21 = df[['Agebin', 'Ad ID', 'click']].groupby(['Agebin', 'Ad ID']).agg(['count', 'mean']).reset_index()

# %%
for i in range(1, 6):
    dfx = df21[df21['Ad ID'] == i]
    plt.plot(dfx['Agebin'], dfx['click']['mean'], 'o--')
plt.legend(['Ad 1', 'Ad 2', 'Ad 3', 'Ad 4', 'Ad 5'])
plt.xlabel('Age bin')
plt.ylabel('CTR')
plt.show()

# %%
# Check behaviour over time

# %%
df['Month'] = df['Date'].apply(lambda x: x[:7])
df.head()
# Out:
#    Customer ID            Date Time  Ad ID Gender  Age    Holiday  Working  \
# 0       129899  2024-09-01 07:03:18      5      M   20  NoHoliday    False
# 1       121047  2024-09-01 07:07:48      3      M   50  NoHoliday    False
# 2       133576  2024-09-01 07:12:39      2      M   47  NoHoliday    False
# 3       112276  2024-09-01 07:13:28      4      M   45  NoHoliday    False
# 4       102275  2024-09-01 07:20:03      3      M   29  NoHoliday    False
#
#    probs  click        Date  Agebin    Month
# 0   0.09      0  2024-09-01       1  2024-09
# 1   0.12      0  2024-09-01       7  2024-09
# 2   0.02      0  2024-09-01       6  2024-09
# 3   0.49      0  2024-09-01       6  2024-09
# 4   0.00      0  2024-09-01       2  2024-09

# %% [markdown]
# # Plot CTR as function of age group

# %%
dft = df[df['Age'] < 40]
print (len(dft))
dft.head()
# Out:
# 61120
#    Customer ID            Date Time  Ad ID Gender  Age    Holiday  Working  \
# 0       129899  2024-09-01 07:03:18      5      M   20  NoHoliday    False
# 4       102275  2024-09-01 07:20:03      3      M   29  NoHoliday    False
# 6       106520  2024-09-01 07:28:21      4      F   30  NoHoliday    False
# 8       117997  2024-09-01 07:37:52      5      F   24  NoHoliday    False
# 9       102939  2024-09-01 07:43:46      4      F   24  NoHoliday    False
#
#    probs  click        Date  Agebin    Month
# 0   0.09      0  2024-09-01       1  2024-09
# 4   0.00      0  2024-09-01       2  2024-09
# 6   0.02      0  2024-09-01       3  2024-09
# 8   0.01      0  2024-09-01       1  2024-09
# 9  -0.00      0  2024-09-01       1  2024-09

# %%
dft2 = dft[['Month', 'Ad ID', 'click']].groupby(['Month', 'Ad ID']).agg(['count', 'mean']).reset_index()
dft2.head()
# Out:
#      Month Ad ID click
#                  count      mean
# 0  2024-09     1   805  0.402484
# 1  2024-09     2   856  0.309579
# 2  2024-09     3   812  0.038177
# 3  2024-09     4   859  0.058207
# 4  2024-09     5   864  0.049769

# %%
for i in range(1,6):
  dftemp = dft2[dft2['Ad ID'] == i]
  plt.plot(dftemp['Month'], dftemp['click']['mean'], 'o--')
  plt.xlabel('Year Month')
  plt.ylabel('CTR')

plt.title('CTR for age group < 40')
plt.legend(['Ad 1', 'Ad 2', 'Ad 3', 'Ad 4', 'Ad 5'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Plot CTR as function of age group & gender

# %%
dft = df[df['Age'] < 40]
dft = dft[dft['Gender'] == 'M']
print (len(dft))
dft2 = dft[['Month', 'Ad ID', 'click']].groupby(['Month', 'Ad ID']).agg(['count', 'mean']).reset_index()
dft2.head()

for i in range(1,6):
  dftemp = dft2[dft2['Ad ID'] == i]
  plt.plot(dftemp['Month'], dftemp['click']['mean'], 'o--')
  plt.xlabel('Year Month')
  plt.ylabel('CTR')

plt.title('CTR for age group < 40, Male')
plt.legend(['Ad 1', 'Ad 2', 'Ad 3', 'Ad 4', 'Ad 5'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 30972

# %%
dft = df[df['Age'] < 40]
dft = dft[dft['Gender'] == 'F']
print (len(dft))
dft2 = dft[['Month', 'Ad ID', 'click']].groupby(['Month', 'Ad ID']).agg(['count', 'mean']).reset_index()
dft2.head()

for i in range(1,6):
  dftemp = dft2[dft2['Ad ID'] == i]
  plt.plot(dftemp['Month'], dftemp['click']['mean'], 'o--')
  plt.xlabel('Year Month')
  plt.ylabel('CTR')

plt.title('CTR for age group < 40, Female')
plt.legend(['Ad 1', 'Ad 2', 'Ad 3', 'Ad 4', 'Ad 5'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 30148
