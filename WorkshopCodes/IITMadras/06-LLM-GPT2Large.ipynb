# %%
# Ref:https://michael-franke.github.io/npNLG/07-LLMs/07b-pretrained-LLMs.html

# %%
from transformers import GPT2TokenizerFast, GPT2LMHeadModel
#from datasets import load_dataset
import torch
import textwrap
import warnings
warnings.filterwarnings('ignore')

# %%
def pretty_print(s):
    print("Output:\n" + 80 * '-')
    print(textwrap.fill(tokenizer.decode(s, skip_special_tokens=True),80))

# %%
##################################################
## instantiating LLM & its tokenizer
##################################################

# model_to_use = "gpt2"
model_to_use = "gpt2-large"

print("Using model: ", model_to_use)

# get the tokenizer for the pre-trained LM you would like to use
tokenizer = GPT2TokenizerFast.from_pretrained(model_to_use)

# instantiate a model (causal LM)
model = GPT2LMHeadModel.from_pretrained(model_to_use,
                                        output_scores=True,
                                        pad_token_id=tokenizer.eos_token_id)

# inspecting the (default) model configuration
# (it is possible to created models with different configurations)
print(model.config)
# Out:
# Using model:  gpt2-large
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e2cb4e896b02> in <cell line: 11>()
#       9
#      10 # get the tokenizer for the pre-trained LM you would like to use
# ---> 11 tokenizer = GPT2TokenizerFast.from_pretrained(model_to_use)
#      12
#      13 # instantiate a model (causal LM)
#
# NameError: name 'GPT2TokenizerFast' is not defined

# %%
##################################################
## autoregressive generation
##################################################

# text to expand
prompt = "What is nuclear fission? Explain it to a high school student"

# translate the prompt into tokens
input_tokens = tokenizer(prompt, return_tensors="pt").input_ids
print(input_tokens)

outputs = model.generate(input_tokens,
                         max_new_tokens=100,
                         do_sample=True,
                         top_k=50,
                       )

print("\nTop-k sampling:\n")
pretty_print(outputs[0])
# Out:
# tensor([[ 2061,   318,  4523,   277,  1480,    30, 48605,   340,   284,   257,
#           1029,  1524,  3710]])
#
# Top-k sampling:
#
# Output:
# --------------------------------------------------------------------------------
# What is nuclear fission? Explain it to a high school student. Nuclear fission is
# when two atoms – nuclei – are split apart in a controlled process in a
# controlled way. A neutron then enters both of the atoms. Once the two nuclei –
# or the fragments of one – collide, they give off energy. Electrons follow the
# collision, which eventually creates a chain reaction. The energy produced by the
# chain reaction is released to the surrounding environment. The process is called
# "fission".  What are the two primary types of nuclear weapons? Nuclear

# %%
outputs = model.generate(input_tokens,
                         max_new_tokens=100,
                         num_beams=6,
                         no_repeat_ngram_size=4,
                         early_stopping=True
                         )

print("\nBeam search:\n")
pretty_print(outputs[0])
# Out:
# Beam search:
#
# Output:
# --------------------------------------------------------------------------------
# What is nuclear fission? Explain it to a high school student.  Nuclear fission
# is the process of splitting atoms into smaller and smaller pieces. This process
# is called nuclear fission because it splits atoms into smaller pieces.  What is
# the difference between fission and fusion?  Fission is the splitting of an atom
# into smaller pieces, while fusion is the fusion of two atoms into a larger one.
# How does nuclear fission work?  When an atom splits, it releases energy in the
# form of heat. This heat
